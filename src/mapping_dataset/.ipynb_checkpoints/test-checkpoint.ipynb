# %%
import pandas as pd

df = pd.read_csv('clean_mapping_dataset.csv')
df.head()
# Out:
#   technique_id is_subtechnique         technique                      tactic  \
# 0        T1622           False  debugger evasion  defense-evasion, discovery
# 1        T1622           False  debugger evasion  defense-evasion, discovery
# 2        T1622           False  debugger evasion  defense-evasion, discovery
# 3        T1622           False  debugger evasion  defense-evasion, discovery
# 4        T1622           False  debugger evasion  defense-evasion, discovery
#
#                 platform data_source    data_component relationship_id  \
# 0  Windows, Linux, macOS     process  os api execution   REL-2022-0150
# 1  Windows, Linux, macOS     process  os api execution   REL-2022-0150
# 2  Windows, Linux, macOS     process  process creation   REL-2022-0146
# 3  Windows, Linux, macOS     process  process creation   REL-2022-0146
# 4  Windows, Linux, macOS     process  process creation   REL-2022-0146
#
#                         name   source  ...      audit_category  \
# 0  Process executed Api call  process  ...  CreateRemoteThread
# 1  Process executed Api call  process  ...                 NaN
# 2       User created Process     user  ...   Detailed Tracking
# 3       User created Process     user  ...       ProcessCreate
# 4       User created Process     user  ...       ProcessCreate
#
#   audit_sub_category                               channel  \
# 0                NaN  microsoft-windows-sysmon/operational
# 1                NaN                                   NaN
# 2   Process Creation                              security
# 3                NaN  microsoft-windows-sysmon/operational
# 4                NaN                                   NaN
#
#                             log_source  \
# 0             microsoft-windows-sysmon
# 1      microsoft defender for endpoint
# 2  microsoft-windows-security-auditing
# 3             microsoft-windows-sysmon
# 4                               sysmon
#
#                                      filter_in  \
# 0                                          NaN
# 1  {"ActionType": "CreateRemoteThreadApiCall"}
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#                                       event_identity  \
# 0  windows|microsoft-windows-sysmon|8|createremot...
# 1  windows|microsoft defender for endpoint|Device...
# 2  windows|microsoft-windows-security-auditing|46...
# 3  windows|microsoft-windows-sysmon|1|process cre...
# 4                   linux|sysmon|1|process creation.
#
#                     source_identity evidence_degree evidence_score  \
# 0  windows|process|os api execution             224         0.0412
# 1  windows|process|os api execution             270         0.0094
# 2  windows|process|process creation             248         0.0238
# 3  windows|process|process creation             248         0.0238
# 4    linux|process|process creation             162         0.0963
#
#                           evidence_confidence_reason
# 0  Evidence score 0.04: this telemetry is shared ...
# 1  Evidence score 0.01: this telemetry is shared ...
# 2  Evidence score 0.02: this telemetry is shared ...
# 3  Evidence score 0.02: this telemetry is shared ...
# 4  Evidence score 0.10: this telemetry is shared ...
#
# [5 rows x 25 columns]

# %%
platform_counts = (
    df.groupby("event_platform")
      .size()
      .sort_values(ascending=False)
)

print(platform_counts)
# Out:
# event_platform
# windows    10110
# linux        965
# dtype: int64

# %%
import pandas as pd 
final_df  = pd.read_csv("C:\\Users\\tahay\\OneDrive\\Desktop\\Attack-Progression-Prediction\\mapping_dataset.csv")

# %%
final_df[final_df['technique_id'] == 'T1046']
# Out:
#      technique_id is_subtechnique                  technique     tactic  \
# 9987        T1046           False  network service discovery  discovery
# 9988        T1046           False  network service discovery  discovery
# 9989        T1046           False  network service discovery  discovery
# 9990        T1046           False  network service discovery  discovery
# 9991        T1046           False  network service discovery  discovery
# 9992        T1046           False  network service discovery  discovery
# 9993        T1046           False  network service discovery  discovery
# 9994        T1046           False  network service discovery  discovery
# 9995        T1046           False  network service discovery  discovery
#
#                                               platform data_source  \
# 9987  Windows, IaaS, Linux, macOS, Containers, Network     command
# 9988  Windows, IaaS, Linux, macOS, Containers, Network     command
# 9989  Windows, IaaS, Linux, macOS, Containers, Network     command
# 9990  Windows, IaaS, Linux, macOS, Containers, Network     command
# 9991  Windows, IaaS, Linux, macOS, Containers, Network     command
# 9992  Windows, IaaS, Linux, macOS, Containers, Network     command
# 9993  Windows, IaaS, Linux, macOS, Containers, Network     command
# 9994  Windows, IaaS, Linux, macOS, Containers, Network     command
# 9995  Windows, IaaS, Linux, macOS, Containers, Network     command
#
#          data_component relationship_id                      name   source  \
# 9987  command execution   REL-2022-0018     User executed Command     user
# 9988  command execution   REL-2022-0018     User executed Command     user
# 9989  command execution   REL-2022-0018     User executed Command     user
# 9990  command execution   REL-2022-0018     User executed Command     user
# 9991  command execution   REL-2022-0131  Process executed Command  process
# 9992  command execution   REL-2022-0131  Process executed Command  process
# 9993  command execution   REL-2022-0131  Process executed Command  process
# 9994  command execution   REL-2022-0131  Process executed Command  process
# 9995  command execution   REL-2022-0131  Process executed Command  process
#
#       ...                         filter_in  \
# 9987  ...                               NaN
# 9988  ...                               NaN
# 9989  ...                               NaN
# 9990  ...  {"ActionType": "ProcessCreated"}
# 9991  ...                               NaN
# 9992  ...                               NaN
# 9993  ...                               NaN
# 9994  ...                               NaN
# 9995  ...  {"ActionType": "ProcessCreated"}
#
#                                          event_identity  \
# 9987  windows|microsoft-windows-security-auditing|46...
# 9988  windows|microsoft-windows-sysmon|1|process cre...
# 9989  windows|microsoft-windows-powershell|4103|modu...
# 9990  windows|microsoft defender for endpoint|Device...
# 9991  windows|microsoft-windows-security-auditing|46...
# 9992  windows|microsoft-windows-sysmon|1|process cre...
# 9993                   linux|sysmon|1|process creation.
# 9994  windows|microsoft-windows-powershell|4103|modu...
# 9995  windows|microsoft defender for endpoint|Device...
#
#                         source_identity evidence_degree evidence_score  \
# 9987  windows|command|command execution             248         0.0404
# 9988  windows|command|command execution             248         0.0404
# 9989  windows|command|command execution             225         0.0606
# 9990  windows|command|command execution             248         0.0404
# 9991  windows|command|command execution             248         0.0404
# 9992  windows|command|command execution             248         0.0404
# 9993    linux|command|command execution             162         0.1290
# 9994  windows|command|command execution             225         0.0606
# 9995  windows|command|command execution             248         0.0404
#
#                              evidence_confidence_reason  \
# 9987  Evidence score 0.04: this telemetry is shared ...
# 9988  Evidence score 0.04: this telemetry is shared ...
# 9989  Evidence score 0.06: this telemetry is shared ...
# 9990  Evidence score 0.04: this telemetry is shared ...
# 9991  Evidence score 0.04: this telemetry is shared ...
# 9992  Evidence score 0.04: this telemetry is shared ...
# 9993  Evidence score 0.13: this telemetry is shared ...
# 9994  Evidence score 0.06: this telemetry is shared ...
# 9995  Evidence score 0.04: this telemetry is shared ...
#
#      telemetry_specificity_score filter_specificity_score completeness_score  \
# 9987                    0.067884                     0.10           0.956140
# 9988                    0.067884                     0.10           0.912281
# 9989                    0.067884                     0.10           0.868421
# 9990                    0.067884                     0.42           0.842105
# 9991                    0.067884                     0.10           0.956140
# 9992                    0.067884                     0.10           0.912281
# 9993                    0.082761                     0.10           0.842105
# 9994                    0.067884                     0.10           0.868421
# 9995                    0.067884                     0.42           0.842105
#
#      relationship_strength
# 9987              0.255170
# 9988              0.246398
# 9989              0.237626
# 9990              0.328363
# 9991              0.255170
# 9992              0.246398
# 9993              0.239801
# 9994              0.237626
# 9995              0.328363
#
# [9 rows x 29 columns]

# %%
techniques = [
    'T1595',
    'T1595.002',
    'T1592',
    'T1046',
    'T1016',
    'T1190',
    'T1505.003',
    'T1059',
    'T1059.001',
    'T1059.004',
    'T1110',
    'T1110.003',
    'T1078',
    'T1548',
    'T1548.003',
    'T1068',
    'T1552.001',
    'T1003',
    'T1003.001',
    'T1003.008',
    'T1082',
    'T1033',
    'T1083',
    'T1087',
    'T1087.002',
    'T1069.002',
    'T1018',
    'T1021',
    'T1021.001',
    'T1021.002',
    'T1021.004',
    'T1105',
    'T1027',
    'T1204.002',
    'T1547.001',
    'T1053.005',
    'T1543.003',
    'T1071',
    'T1071.001',
    'T1071.004',
    'T1049',
    'T1005',
    'T1119',
    'T1560',
    'T1560.001',
    'T1041',
    'T1048'
]

n = 0
for t in techniques:
    print(f"Technique: {t}")
    found = len(final_df[final_df['technique_id'] == t])
    print(found)
    print("\n")
    if found == 0:
        n+=1

print(f"Number of techniques not found: {n}")
# Out:
# Technique: T1595
# 0
#
#
# Technique: T1595.002
# 0
#
#
# Technique: T1592
# 0
#
#
# Technique: T1046
# 9
#
#
# Technique: T1016
# 26
#
#
# Technique: T1190
# 0
#
#
# Technique: T1505.003
# 24
#
#
# Technique: T1059
# 32
#
#
# Technique: T1059.001
# 28
#
#
# Technique: T1059.004
# 3
#
#
# Technique: T1110
# 19
#
#
# Technique: T1110.003
# 10
#
#
# Technique: T1078
# 26
#
#
# Technique: T1548
# 44
#
#
# Technique: T1548.003
# 4
#
#
# Technique: T1068
# 2
#
#
# Technique: T1552.001
# 14
#
#
# Technique: T1003
# 41
#
#
# Technique: T1003.001
# 26
#
#
# Technique: T1003.008
# 1
#
#
# Technique: T1082
# 21
#
#
# Technique: T1033
# 41
#
#
# Technique: T1083
# 21
#
#
# Technique: T1087
# 24
#
#
# Technique: T1087.002
# 21
#
#
# Technique: T1069.002
# 19
#
#
# Technique: T1018
# 99
#
#
# Technique: T1021
# 110
#
#
# Technique: T1021.001
# 80
#
#
# Technique: T1021.002
# 83
#
#
# Technique: T1021.004
# 14
#
#
# Technique: T1105
# 82
#
#
# Technique: T1027
# 26
#
#
# Technique: T1204.002
# 17
#
#
# Technique: T1547.001
# 35
#
#
# Technique: T1053.005
# 25
#
#
# Technique: T1543.003
# 43
#
#
# Technique: T1071
# 0
#
#
# Technique: T1071.001
# 0
#
#
# Technique: T1071.004
# 0
#
#
# Technique: T1049
# 21
#
#
# Technique: T1005
# 31
#
#
# Technique: T1119
# 19
#
#
# Technique: T1560
# 31
#
#
# Technique: T1560.001
# 26
#
#
# Technique: T1041
# 89
#
#
# Technique: T1048
# 89
#
#
# Number of techniques not found: 7

# %%
techniques = [
    'T1595',
    'T1595.002',
    'T1592',
    'T1046',
    'T1016',
    'T1190',
    'T1505.003',
    'T1059',
    'T1059.001',
    'T1059.004',
    'T1110',
    'T1110.003',
    'T1078',
    'T1548',
    'T1548.003',
    'T1068',
    'T1552.001',
    'T1003',
    'T1003.001',
    'T1003.008',
    'T1082',
    'T1033',
    'T1083',
    'T1087',
    'T1087.002',
    'T1069.002',
    'T1018',
    'T1021',
    'T1021.001',
    'T1021.002',
    'T1021.004',
    'T1105',
    'T1027',
    'T1204.002',
    'T1547.001',
    'T1053.005',
    'T1543.003',
    'T1071',
    'T1071.001',
    'T1071.004',
    'T1049',
    'T1005',
    'T1119',
    'T1560',
    'T1560.001',
    'T1041',
    'T1048'
]
print(len(techniques))
# Out:
# 47
